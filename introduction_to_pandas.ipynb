# %% [markdown]
# <a href="https://colab.research.google.com/github/nemalikantikrish/python/blob/main/introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Upload a CSV file
# from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3e31294-93e5-471c-ac29-5a802fef7e92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3e31294-93e5-471c-ac29-5a802fef7e92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'Credit_Card_Applications[1].txt': b'CustomerID,A1,A2,A3,A4,A5,A6,A7,A8,A9,A10,A11,A12,A13,A14,Class\r\n15776156,1,22.08,11.46,2,4,4,1.585,0,0,0,1,2,100,1213,0\r\n15739548,0,22.67,7,2,8,4,0.165,0,0,0,0,2,160,1,0\r\n15662854,0,29.58,1.75,1,4,4,1.25,0,0,0,1,2,280,1,0\r\n15687688,0,21.67,11.5,1,5,3,0,1,1,11,1,2,0,1,1\r\n15715750,1,20.17,8.17,2,6,4,1.96,1,1,14,0,2,60,159,1\r\n15571121,0,15.83,0.585,2,8,8,1.5,1,1,2,0,2,100,1,1\r\n15726466,1,17.42,6.5,2,3,4,0.125,0,0,0,0,2,60,101,0\r\n15660390,0,58.67,4.46,2,11,8,3.04,1,1,6,0,2,43,561,1\r\n15663942,1,27.83,1,1,2,8,3,0,0,0,0,2,176,538,0\r\n15638610,0,55.75,7.08,2,4,8,6.75,1,1,3,1,2,100,51,0\r\n15644446,1,33.5,1.75,2,14,8,4.5,1,1,4,1,2,253,858,1\r\n15585892,1,41.42,5,2,11,8,5,1,1,6,1,2,470,1,1\r\n15609356,1,20.67,1.25,1,8,8,1.375,1,1,3,1,2,140,211,0\r\n15803378,1,34.92,5,2,14,8,7.5,1,1,6,1,2,0,1001,1\r\n15599440,1,58.58,2.71,2,8,4,2.415,0,0,0,1,2,320,1,0\r\n15692408,1,48.08,6.04,2,4,4,0.04,0,0,0,0,2,0,2691,1\r\n15683168,1,29.58,4.5,2,9,4,7.
# ...

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/Credit_Card_Applications[1].txt')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
# To read a data cell from a selected row or column
# loc - iloc
# dframe.loc[rows,columnnames]
dataset.loc[[0,1,5],['A11','A2','A1']]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.iloc[[0,1,5],[11,2,1]]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
# Pandas - 2 types - series,Data frames
#series - [12,3,4,56,7,8,90]
#Dataframes - []

# %%
# Change the number of elements (Visible in the Code Editor Output) - Jupter Notebook - VS code - Anaconda
import pandas as pd # Import the pandas library and assign it to the alias 'pd'
pd.set_option('display.max_columns',15)
pd.set_option('display.max_rows',50)

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

  idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [72,
#   50,
#   91,
#   26,
#   96,
#   62,
#   9,
#   74,
#   65,
#   82,
#   35,
#   100,
#   7,
#   76,
#   82,
#   74,
#   63,
#   14,
#   48,
#   11,
#   82,
#   60,
#   85,
#   78,
#   3,
#   6,
#   71,
#   93,
#   7,
#   48,
#   55,
#   91,
#   17,
#   18,
#   53,
#   71,
#   46,
#   62,
#   42,
#   84,
#   88,
#   83,
#   61,
#   56,
#   20,
#   84,
#   42,
#   67,
#   25,
#   23,
#   48,
#   89,
#   32,
#   74,
#   74,
#   56,
#   81,
#   33,
#   51,
#   23,
#   89,
#   25,
#   56,
#   6,
#   81,
#   4,
#   63,
#   78,
#   87,
#   0,
#   4,
#   37,
#   5,
#   88,
#   65,
#   46,
#   48,
#   31,
#   21,
#   88,
#   40,
#   62,
#   62,
#   29,
#   45,
#   84,
#   5,
#   25,
#   80,
#   86,
#   27,
#   79,
#   41,
#   59,
#   86,
#   31,
#   98,
#   60,
#   55,
#   53],
#  'Height': [80,
#   17,
#   63,
#   32,
#   69,
#   21,
#   88,
#   29,
#   72,
#   71,
#   99,
#   40,
#   39,
#   46,
#   60,
#   88,
#   15,
#   0,
#   0,
#   99,
#   72,
#   75,
#   29,
#   56,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    72      80      46     54
# 1    50      17      46     83
# 2    91      63      41     53
# 3    26      32      44     26
# 4    96      69      86     69
# ..  ...     ...     ...    ...
# 95   31       9      65     40
# 96   98      97      40     72
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   27      70      46     24
# 91   79      22      76     70
# 92   41      82      82     82
# 93   59      63      84     57
# 94   86       2      16      9
# 95   31       9      65     40
# 96   98      97      40     72
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    72      80      46     54
# 1    50      17      46     83
# 2    91      63      41     53
# 3    26      32      44     26
# 4    96      69      86     69
# ..  ...     ...     ...    ...
# 95   31       9      65     40
# 96   98      97      40     72
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95
#
# [100 rows x 4 columns]

# %%
# Filter
filter1 = df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 4    96      69      86     69
# 7    74      29      79     45
# 9    82      71      60     84
# 10   35      99      96     42
# 13   76      46      92     23
# ..  ...     ...     ...    ...
# 93   59      63      84     57
# 95   31       9      65     40
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95
#
# [56 rows x 4 columns]

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 4    96      69      86     69
# 7    74      29      79     45
# 9    82      71      60     84
# 10   35      99      96     42
# 13   76      46      92     23
# ..  ...     ...     ...    ...
# 93   59      63      84     57
# 95   31       9      65     40
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95
#
# [56 rows x 4 columns]

# %%
filter2 = df1['Age']>50

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 4    96      69      86     69
# 7    74      29      79     45
# 9    82      71      60     84
# 13   76      46      92     23
# 14   82      60      60     46
# 15   74      88      89     93
# 16   63      15      56     62
# 20   82      72      95     92
# 21   60      75      62     77
# 26   71      82      88     41
# 30   55      58      52      7
# 31   91      89      82     16
# 37   62      92      81     92
# 39   84      22      64     47
# 41   83      12      53     69
# 42   61      23      98     39
# 43   56      61      74     43
# 47   67      14      62     29
# 51   89      31      79      0
# 56   81      35      71     58
# 62   56      50      71      9
# 66   63      40      75     91
# 68   87      65      64     90
# 73   88      17      58     14
# 74   65      33      59     70
# 79   88      90      87     46
# 85   84      68      57     84
# 88   80       9      55     18
# 89   86      74      79     21
# ...

# %%
df1.loc[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    72      80      46     54
# 2    91      63      41     53
# 4    96      69      86     69
# 5    62      21      32     18
# 7    74      29      79     45
# ..  ...     ...     ...    ...
# 95   31       9      65     40
# 96   98      97      40     72
# 97   60      21      68     46
# 98   55      36      56     91
# 99   53      19      92     95
#
# [79 rows x 4 columns]

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    53.480000   48.350000   54.100000   50.330000
# std     28.216508   29.677858   26.308389   29.235738
# min      0.000000    0.000000    0.000000    0.000000
# 25%     30.500000   21.750000   35.750000   23.750000
# 50%     56.000000   48.500000   56.000000   46.500000
# 75%     79.250000   72.250000   75.250000   77.000000
# max    100.000000  100.000000   98.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    72      80
# 1    50      17
# 2    91      63
# 3    26      32
# 4    96      69
# ..  ...     ...
# 95   31       9
# 96   98      97
# 97   60      21
# 98   55      36
# 99   53      19
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   72      80
# 3   26      32

# %%
df1[0::2].describe()
# Out:
#              Age      Height     Weight      Speed
# count  50.000000   50.000000  50.000000  50.000000
# mean   52.180000   49.100000  51.960000  52.700000
# std    28.171262   29.436372  27.383117  29.807717
# min     3.000000    0.000000   4.000000   2.000000
# 25%    32.750000   27.500000  32.750000  25.500000
# 50%    54.000000   52.000000  52.000000  53.500000
# 75%    78.500000   71.500000  71.000000  82.750000
# max    98.000000  100.000000  98.000000  96.000000
